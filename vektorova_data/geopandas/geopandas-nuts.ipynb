# %% [markdown]
# # Úvod do GeoPandas

# %% [markdown]
# ## Nahrání dat

# %%
filename = 'demo_r_pjangrp3_linear.csv.gz'

import pandas as pd
nuts_data = pd.read_csv(filename, compression='gzip')
nuts_data
# Out:
#                            DATAFLOW        LAST UPDATE freq sex unit    age  \
# 0        ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   F   NR  TOTAL
# 1        ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   F   NR  TOTAL
# 2        ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   F   NR  TOTAL
# 3        ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   F   NR  TOTAL
# 4        ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   F   NR  TOTAL
# ...                             ...                ...  ...  ..  ...    ...
# 1125890  ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   T   NR  Y_LT5
# 1125891  ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   T   NR  Y_LT5
# 1125892  ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   T   NR  Y_LT5
# 1125893  ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   T   NR  Y_LT5
# 1125894  ESTAT:DEMO_R_PJANGRP3(1.0)  28/09/23 23:00:00    A   T   NR  Y_LT5
#
#            geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0           AL         2014    1430827      NaN
# 1           AL         2015    1424597      NaN
# 2           AL         2016    1417141      NaN
# 3           AL         2017    1423050      NaN
# 4           AL         2018    1431715      NaN
# ...        ...          ...        ...      ...
# 1125890  UKN16         2015       7764      NaN
# 1125891  UKN16         2016       7720      NaN
# 1125892  UKN16         2017       7712      NaN
# 1125893  UKN16         2018       7659      NaN
# 1125894  UKN16         2019       7654      NaN
#
# [1125895 rows x 10 columns]

# %% [markdown]
# V tabulce chybí geografická část popisu NUTS jednotech. Pro další práci zvolíme data ve formátu Esri Shapefile.

# %%
import geopandas as gpd
nuts = gpd.read_file("NUTS_RG_20M_2021_3035.shp")
nuts
# Out:
#      NUTS_ID  LEVL_CODE CNTR_CODE               NAME_LATN  \
# 0         FR          0        FR                  France
# 1         HR          0        HR                Hrvatska
# 2         HU          0        HU            Magyarország
# 3         AL          0        AL               Shqipëria
# 4         AT          0        AT              Österreich
# ...      ...        ...       ...                     ...
# 2005   TRC21          3        TR               Şanlıurfa
# 2006   TRC22          3        TR              Diyarbakır
# 2007   NO0B2          3        NO                Svalbard
# 2008    NO0B          2        NO  Jan Mayen and Svalbard
# 2009   NO0B1          3        NO               Jan Mayen
#
#                    NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE    FID  \
# 0                     France         0.0          0           0     FR
# 1                   Hrvatska         0.0          0           0     HR
# 2               Magyarország         0.0          0           0     HU
# 3                  Shqipëria         0.0          0           0     AL
# 4                 Österreich         0.0          0           0     AT
# ...                      ...         ...        ...         ...    ...
# 2005               Şanlıurfa         4.0          2           3  TRC21
# 2006              Diyarbakır         4.0          2           3  TRC22
# 2007                Svalbard         3.0          3           1  NO0B2
# 2008  Jan Mayen and Svalbard         NaN          0           0   NO0B
# 2009               Jan Mayen         3.0          3           1  NO0B1
#
#                                                geometry
# 0     MULTIPOLYGON (((9954236.116 -3059379.316, 9961...
# 1     MULTIPOLYGON (((4827385.889 2618351.326, 48483...
# 2     POLYGON ((5214660.069 2880853.832, 5216710.220...
# 3     POLYGON ((5129579.170 2204098.752, 5148385.473...
# 4     POLYGON ((4742889.368 2876362.725, 4783217.798...
# ...                                                 ...
# 2005  POLYGON ((6904684.585 2120354.802, 6938677.828...
# 2006  POLYGON ((6989716.599 2273670.524, 6982786.486...
# 2007  MULTIPOLYGON (((4754167.335 6382461.409, 47465...
# 2008  MULTIPOLYGON (((4754167.335 6382461.409, 47465...
# 2009  POLYGON ((3642785.362 5404637.884, 3624291.510...
#
# [2010 rows x 10 columns]

# %% [markdown]
# Vybere prvky na NUTS urovni 0.

# %%
nuts0 = nuts[nuts["LEVL_CODE"] == 0]
nuts0.head()
# Out:
#   NUTS_ID  LEVL_CODE CNTR_CODE     NAME_LATN     NUTS_NAME  MOUNT_TYPE  \
# 0      FR          0        FR        France        France         0.0
# 1      HR          0        HR      Hrvatska      Hrvatska         0.0
# 2      HU          0        HU  Magyarország  Magyarország         0.0
# 3      AL          0        AL     Shqipëria     Shqipëria         0.0
# 4      AT          0        AT    Österreich    Österreich         0.0
#
#    URBN_TYPE  COAST_TYPE FID  \
# 0          0           0  FR
# 1          0           0  HR
# 2          0           0  HU
# 3          0           0  AL
# 4          0           0  AT
#
#                                             geometry
# 0  MULTIPOLYGON (((9954236.116 -3059379.316, 9961...
# 1  MULTIPOLYGON (((4827385.889 2618351.326, 48483...
# 2  POLYGON ((5214660.069 2880853.832, 5216710.220...
# 3  POLYGON ((5129579.170 2204098.752, 5148385.473...
# 4  POLYGON ((4742889.368 2876362.725, 4783217.798...

# %% [markdown]
# Vybrané prvky zobrazíme v interaktivní mapě.

# %%
nuts0.explore()
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_122dc722ce80b42a85fe99241d6a59e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_122dc722ce80b42a85fe99241d6a59e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_122dc722ce80b42a85fe99241d6a59e3 = L.map(
#                 &quot;map_122dc722ce80b42a85fe99241d6a59e3&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_122dc722ce80b42a85fe99241d6a59e3);
#
#
#
#
#
#             var tile_layer_51bda2c92fe73eb5d3f8eada517dfca7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_122dc722ce80b42a85fe99241d6a59e3);
#
#
#             map_122dc722ce80b42a85fe99241d6a59e3.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_bc843f34e36617fee805969bbf9733f0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bc843f34e36617fee805969bbf9733f0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bc843f34e36617fee805969bbf9733f0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bc843f34e36617fee805969bbf9733f0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bc843f34e36617fee805969bbf9733f0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bc843f34e36617fee805969bbf9733f0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bc843f34e36617fee805969bbf9733f0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bc843f34e36617fee805969bbf9733f0 = L.geoJson(null, {
#                 onEachFeature: geo_json_bc843f34e36617fee805969bbf9733f0_onEachFeature,
#
#                 style: geo_json_bc843f34e36617fee805969bbf9733f0_styler,
#                 pointToLayer: geo_json_bc843f34e36617fee805969bbf9733f0_pointToLayer
#         });
#
#         function geo_json_bc843f34e36617fee805969bbf9733f0_add (data) {
#             geo_json_bc843f34e36617fee805969bbf9733f0
#                 .addData(data)
#                 .addTo(map_122dc722ce80b42a85fe99241d6a59e3);
#         }
#             geo_json_bc843f34e36617fee805969bbf9733f0_add({&quot;bbox&quot;: [-63.08825311685313, -21.390765204928847, 55.83808178617596, 80.77475800882081], &quot;features&quot;: [{&quot;bbox&quot;: [-63.08825311685313, -21.390765204928847, 55.83808178617596, 51.0893819972857], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[55.214714260201475, -21.03851208596236], [55.273919700912415, -21.000572522645765], [55.28509578405292, -20.92360339391122], [55.32105184935726, -20.932164313266973], [55.450576288301065, -20.86976035777267], [55.64862247821309, -20.913956010200614], [55.708120433600605, -21.02544231709615], [55.83808178617596, -21.183548501003127], [55.804001638068996, -21.261

# %% [markdown]
# ### Přidání informací o obyvatelstvu

# %%
def population_by_nuts(df, year, level=0, sex='T', nuts=None):
    data = df[(df["TIME_PERIOD"] == year) & (df["sex"] == sex) & (df["age"] == 'TOTAL') & (df["geo"].apply(lambda x: len(x) == level+2))]
    if nuts is not None:
        data = data[data["geo"].str.match(nuts)]

        
    return data[["geo", "OBS_VALUE"]]

population_by_nuts(nuts_data, 2022).head()
# Out:
#        geo  OBS_VALUE
# 752124  AL    2793592
# 752286  AT    8978929
# 752718  BE   11617623
# 753305  BG    6838937
# 753638  CH    8738791

# %%
popu = population_by_nuts(nuts_data, 2022)
nuts0_popu = pd.merge(nuts0, popu, how='left', left_on='NUTS_ID', right_on='geo')
nuts0_popu.head()
# Out:
#   NUTS_ID  LEVL_CODE CNTR_CODE     NAME_LATN     NUTS_NAME  MOUNT_TYPE  \
# 0      FR          0        FR        France        France         0.0
# 1      HR          0        HR      Hrvatska      Hrvatska         0.0
# 2      HU          0        HU  Magyarország  Magyarország         0.0
# 3      AL          0        AL     Shqipëria     Shqipëria         0.0
# 4      AT          0        AT    Österreich    Österreich         0.0
#
#    URBN_TYPE  COAST_TYPE FID  \
# 0          0           0  FR
# 1          0           0  HR
# 2          0           0  HU
# 3          0           0  AL
# 4          0           0  AT
#
#                                             geometry geo   OBS_VALUE
# 0  MULTIPOLYGON (((9954236.116 -3059379.316, 9961...  FR  67871925.0
# 1  MULTIPOLYGON (((4827385.889 2618351.326, 48483...  HR   3862305.0
# 2  POLYGON ((5214660.069 2880853.832, 5216710.220...  HU   9689010.0
# 3  POLYGON ((5129579.170 2204098.752, 5148385.473...  AL   2793592.0
# 4  POLYGON ((4742889.368 2876362.725, 4783217.798...  AT   8978929.0

# %% [markdown]
# Zobrazíme prvky znázorňující množství obyvatel.

# %%
nuts0_popu.explore(column='OBS_VALUE', legend=False, cmap='OrRd')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de6fb1fedeeec3e1addd7627d0df6659 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de6fb1fedeeec3e1addd7627d0df6659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de6fb1fedeeec3e1addd7627d0df6659 = L.map(
#                 &quot;map_de6fb1fedeeec3e1addd7627d0df6659&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_de6fb1fedeeec3e1addd7627d0df6659);
#
#
#
#
#
#             var tile_layer_4279b81117b28bba729c43136c93f91b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de6fb1fedeeec3e1addd7627d0df6659);
#
#
#             map_de6fb1fedeeec3e1addd7627d0df6659.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_5020d1dd5fce7087781187f74d69d311_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#c71b12&quot;, &quot;fillColor&quot;: &quot;#c71b12&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fff2e0&quot;, &quot;fillColor&quot;: &quot;#fff2e0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fee9cb&quot;, &quot;fillColor&quot;: &quot;#fee9cb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#fff3e3&quot;, &quot;fillColor&quot;: &quot;#fff3e3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#feeace&quot;, &quot;fillColor&quot;: &quot;#feeace&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#fee6c4&quot;, &quot;fillColor&quot;: &quot;#fee6c4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#feeed5&quot;, &quot;fillColor&quot;: &quot;#feeed5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#feebcf&quot;, &quot;fillColor&quot;: &quot;#feebcf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fff6ea&quot;, &quot;fillColor&quot;: &quot;#fff6ea&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;13&quot;: case &quot;18&quot;: case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#fee8c9&quot;, &quot;fillColor&quot;: &quot;#fee8c9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#860000&quot;, &quot;fillColor&quot;: &quot;#860000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#feefd9&quot;, &quot;fillColor&quot;: &quot;#feefd9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fff6e9&quot;, &quot;fillColor&quot;: &quot;#fff6e9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#fff0db&quot;, &quot;fillColor&quot;: &quot;#fff0db&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#f67a51&quot;, &quot;fillColor&quot;: &quot;#f67a51&quot;, &quot;fillOpacity&quot;: 0.5

# %% [markdown]
# Definujeme novou funkci, která výpočet automatizuje.

# %%
def nuts_population(df_geo, df_data, year, level):
    nuts_level = df_geo[df_geo["LEVL_CODE"] == level]
    popu = population_by_nuts(df_data, year, level)
    return pd.merge(nuts_level, popu, how='left', left_on='NUTS_ID', right_on='geo')
    
nuts_popu = nuts_population(nuts, nuts_data, 2022, 1)
nuts_popu
nuts_popu.explore(column='OBS_VALUE', legend=False, cmap='OrRd')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efcbce14be196c580148c9cd1a48daa0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efcbce14be196c580148c9cd1a48daa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efcbce14be196c580148c9cd1a48daa0 = L.map(
#                 &quot;map_efcbce14be196c580148c9cd1a48daa0&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_efcbce14be196c580148c9cd1a48daa0);
#
#
#
#
#
#             var tile_layer_5b105ecd45adc22d922553efc05ba113 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efcbce14be196c580148c9cd1a48daa0);
#
#
#             map_efcbce14be196c580148c9cd1a48daa0.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_24b49b314a5f2103bbedfed9e4e3398a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#feefd9&quot;, &quot;fillColor&quot;: &quot;#feefd9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fdbb85&quot;, &quot;fillColor&quot;: &quot;#fdbb85&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;42&quot;: case &quot;80&quot;: case &quot;82&quot;: case &quot;98&quot;:
#                     return {&quot;color&quot;: &quot;#fddbad&quot;, &quot;fillColor&quot;: &quot;#fddbad&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;90&quot;:
#                     return {&quot;color&quot;: &quot;#fedfb4&quot;, &quot;fillColor&quot;: &quot;#fedfb4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;#fdddb1&quot;, &quot;fillColor&quot;: &quot;#fdddb1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#fc925e&quot;, &quot;fillColor&quot;: &quot;#fc925e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fff1de&quot;, &quot;fillColor&quot;: &quot;#fff1de&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#f3714d&quot;, &quot;fillColor&quot;: &quot;#f3714d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fff6ea&quot;, &quot;fillColor&quot;: &quot;#fff6ea&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;73&quot;: case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;#fee4bf&quot;, &quot;fillColor&quot;: &quot;#fee4bf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;93&quot;: case &quot;112&quot;:
#                     return {&quot;color&quot;: &quot;#fdd9aa&quot;, &quot;fillColor&quot;: &quot;#fdd9aa&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;77&quot;:
#                     return {&quot;color&quot;: &quot;#feebd0&quot;, &quot;fillColor&quot;: &quot;#feebd0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fee0b7&quot;, &quot;fillColor&quot;: &quot;#fee0b7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;57&quot;:
#                     return {&quot;color&quot;: &quot;#fddbac&quot;, &quot;fillColor&quot;: &quot;#fddbac&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&

# %%
nuts_population(nuts, nuts_data, 2014, 2).explore(column='OBS_VALUE', legend=False, cmap='OrRd')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1e57a9ef050876ec557eef1b53822a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1e57a9ef050876ec557eef1b53822a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1e57a9ef050876ec557eef1b53822a8 = L.map(
#                 &quot;map_b1e57a9ef050876ec557eef1b53822a8&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b1e57a9ef050876ec557eef1b53822a8);
#
#
#
#
#
#             var tile_layer_83fa009e8a378acd6d964eda7fe616c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b1e57a9ef050876ec557eef1b53822a8);
#
#
#             map_b1e57a9ef050876ec557eef1b53822a8.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_73347ad957117a1d2ee4dd26d3732e67_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;18&quot;: case &quot;61&quot;: case &quot;117&quot;: case &quot;123&quot;: case &quot;158&quot;: case &quot;200&quot;: case &quot;240&quot;: case &quot;247&quot;: case &quot;249&quot;:
#                     return {&quot;color&quot;: &quot;#feebcf&quot;, &quot;fillColor&quot;: &quot;#feebcf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;96&quot;: case &quot;110&quot;: case &quot;121&quot;: case &quot;164&quot;: case &quot;283&quot;:
#                     return {&quot;color&quot;: &quot;#fee9cb&quot;, &quot;fillColor&quot;: &quot;#fee9cb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;3&quot;: case &quot;9&quot;: case &quot;30&quot;: case &quot;32&quot;: case &quot;43&quot;: case &quot;54&quot;: case &quot;100&quot;: case &quot;149&quot;:
#                     return {&quot;color&quot;: &quot;#feedd4&quot;, &quot;fillColor&quot;: &quot;#feedd4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#fdce98&quot;, &quot;fillColor&quot;: &quot;#fdce98&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;160&quot;: case &quot;246&quot;:
#                     return {&quot;color&quot;: &quot;#fddeb3&quot;, &quot;fillColor&quot;: &quot;#fddeb3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;22&quot;: case &quot;73&quot;: case &quot;76&quot;: case &quot;185&quot;: case &quot;229&quot;: case &quot;270&quot;: case &quot;291&quot;:
#                     return {&quot;color&quot;: &quot;#fee4c0&quot;, &quot;fillColor&quot;: &quot;#fee4c0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;23&quot;: case &quot;40&quot;: case &quot;52&quot;: case &quot;148&quot;: case &quot;172&quot;: case &quot;292&quot;: case &quot;298&quot;: case &quot;299&quot;:
#                     return {&quot;color&quot;: &quot;#fee8c9&quot;, &quot;fillColor&quot;: &quot;#fee8c9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;101&quot;:
#                     return {&quot;color&quot;: &quot;#fdc791&quot;, &quot;fillColor&quot;: &quot;#fdc791&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;31&quot;: case &quot;48&quot;: case &quot;62&quot;: case &quot;66&quot;: case &quot;91&quot;: case &quot;192&quot;: case &quot;215&quot;: case &quot;273&quot;: case &quot;300&quot;: case &quot;314&quot;:
#                     return {&quot;color&quot;: &quot;#feeed7&quot;, &quot;fillColor&quot;: &quot;#feeed7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;42&quot;: case &quot;72&quot;: case &quot;150&quot;: case &quot;162&quot;: case &quot;183&quot;:
#                     return {&quot;color&quot;: &quot;#feefd8&quot;, &quot;fil

# %% [markdown]
# ## Hustota obyvatelstva

# %%
nuts0_popu.area.head()
# Out:
# 0    6.387388e+11
# 1    5.658665e+10
# 2    9.296786e+10
# 3    2.866265e+10
# 4    8.385113e+10
# dtype: float64

# %% [markdown]
# Vypočteme hustotu obyvatelstva (počet osob/km2).

# %%
(nuts0_popu["OBS_VALUE"] / (nuts0_popu.area / 1e6)).head(10)
# Out:
# 0    106.259284
# 1     68.254707
# 2    104.218925
# 3     97.464550
# 4    107.081788
# 5    377.748627
# 6     61.396334
# 7    212.851778
# 8     97.901453
# 9    133.296882
# dtype: float64

# %%
nuts0_popu["density"] = nuts0_popu["OBS_VALUE"] / (nuts0_popu.area / 1e6)
nuts0_popu.head()
# Out:
#   NUTS_ID  LEVL_CODE CNTR_CODE     NAME_LATN     NUTS_NAME  MOUNT_TYPE  \
# 0      FR          0        FR        France        France         0.0
# 1      HR          0        HR      Hrvatska      Hrvatska         0.0
# 2      HU          0        HU  Magyarország  Magyarország         0.0
# 3      AL          0        AL     Shqipëria     Shqipëria         0.0
# 4      AT          0        AT    Österreich    Österreich         0.0
#
#    URBN_TYPE  COAST_TYPE FID  \
# 0          0           0  FR
# 1          0           0  HR
# 2          0           0  HU
# 3          0           0  AL
# 4          0           0  AT
#
#                                             geometry geo   OBS_VALUE  \
# 0  MULTIPOLYGON (((9954236.116 -3059379.316, 9961...  FR  67871925.0
# 1  MULTIPOLYGON (((4827385.889 2618351.326, 48483...  HR   3862305.0
# 2  POLYGON ((5214660.069 2880853.832, 5216710.220...  HU   9689010.0
# 3  POLYGON ((5129579.170 2204098.752, 5148385.473...  AL   2793592.0
# 4  POLYGON ((4742889.368 2876362.725, 4783217.798...  AT   8978929.0
#
#       density
# 0  106.259284
# 1   68.254707
# 2  104.218925
# 3   97.464550
# 4  107.081788

# %%
nuts0_popu.dropna(subset=["OBS_VALUE"]).explore(column='density', legend=True, cmap='OrRd')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e32e3a6d8324e1488a211fe96c551c77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e32e3a6d8324e1488a211fe96c551c77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e32e3a6d8324e1488a211fe96c551c77 = L.map(
#                 &quot;map_e32e3a6d8324e1488a211fe96c551c77&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e32e3a6d8324e1488a211fe96c551c77);
#
#
#
#
#
#             var tile_layer_3b81fffe16860e633689c0101914947f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e32e3a6d8324e1488a211fe96c551c77);
#
#
#             map_e32e3a6d8324e1488a211fe96c551c77.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_fcf4d5bc8df7848a3ccb947a87cfc7b1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#fff1dd&quot;, &quot;fillColor&quot;: &quot;#fff1dd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fff3e3&quot;, &quot;fillColor&quot;: &quot;#fff3e3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;8&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#fff1de&quot;, &quot;fillColor&quot;: &quot;#fff1de&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#fdddb0&quot;, &quot;fillColor&quot;: &quot;#fdddb0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fff4e4&quot;, &quot;fillColor&quot;: &quot;#fff4e4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#feeacc&quot;, &quot;fillColor&quot;: &quot;#feeacc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#feefd9&quot;, &quot;fillColor&quot;: &quot;#feefd9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#fee8c9&quot;, &quot;fillColor&quot;: &quot;#fee8c9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#fff6e9&quot;, &quot;fillColor&quot;: &quot;#fff6e9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#fff2e1&quot;, &quot;fillColor&quot;: &quot;#fff2e1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#fff3e2&quot;, &quot;fillColor&quot;: &quot;#fff3e2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;#fff7eb&quot;, &quot;fillColor&quot;: &quot;#fff7eb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#fff7ec&quot;, &quot;fillColor&quot;: &quot;#fff7ec&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#fff2e0&quot;, &quot;fillColor&quot;: &quot;#fff2e0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;wei

# %%
mean = nuts0_popu["density"].mean()
nuts0_popu.explore(column='density', legend=True, cmap='OrRd', vmax=mean)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba482645b1413b77abcbb137afe8e79d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba482645b1413b77abcbb137afe8e79d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba482645b1413b77abcbb137afe8e79d = L.map(
#                 &quot;map_ba482645b1413b77abcbb137afe8e79d&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ba482645b1413b77abcbb137afe8e79d);
#
#
#
#
#
#             var tile_layer_62ba79656bb6cc9c8309c8c1f0aa7d8e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba482645b1413b77abcbb137afe8e79d);
#
#
#             map_ba482645b1413b77abcbb137afe8e79d.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_ebe43e407afc2802631a642cb42cf0cf_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#ef6447&quot;, &quot;fillColor&quot;: &quot;#ef6447&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fdb57e&quot;, &quot;fillColor&quot;: &quot;#fdb57e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#f06849&quot;, &quot;fillColor&quot;: &quot;#f06849&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#f4764f&quot;, &quot;fillColor&quot;: &quot;#f4764f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#ee6246&quot;, &quot;fillColor&quot;: &quot;#ee6246&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fdbf89&quot;, &quot;fillColor&quot;: &quot;#fdbf89&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#f4754f&quot;, &quot;fillColor&quot;: &quot;#f4754f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#cb2015&quot;, &quot;fillColor&quot;: &quot;#cb2015&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#c71b12&quot;, &quot;fillColor&quot;: &quot;#c71b12&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fee3bd&quot;, &quot;fillColor&quot;: &quot;#fee3bd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#fc9b66&quot;, &quot;fillColor&quot;: &quot;#fc9b66&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#fdab75&quot;, &quot;fillColor&quot;: &quot;#fdab75&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#f77d52&quot;, &quot;fillColor&quot;: &quot;#f77d52&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#feeed7&quot;, &quot;fillColor&quot;: &quot;#feeed7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#fff7ec&quot;, &quot;fillColor&quot;: &q

# %% [markdown]
# ### Časová řada

# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None) 

nuts_dens = nuts[nuts["LEVL_CODE"] == 0]

years = nuts_data["TIME_PERIOD"].unique()
for year in years:
    print(f"{year}...")
    nuts_popu_year = nuts_population(nuts, nuts_data, year, 0)
    nuts_dens[f"density_{year}"] = nuts_popu_year["OBS_VALUE"] / (nuts_popu_year.area / 1e6)
# Out:
# 2014...
# 2015...
# 2016...
# 2017...
# 2018...
# 2019...
# 2020...
# 2021...
# 2022...

# %%
def show_density(df, year, base="density"):
    column = f"{base}_{year}"
    return df.explore(column, legend=True, cmap='OrRd')

show_density(nuts_dens, 2022)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c1e7dd06326c9aa6310e71a4ab13930 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c1e7dd06326c9aa6310e71a4ab13930&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c1e7dd06326c9aa6310e71a4ab13930 = L.map(
#                 &quot;map_2c1e7dd06326c9aa6310e71a4ab13930&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2c1e7dd06326c9aa6310e71a4ab13930);
#
#
#
#
#
#             var tile_layer_fcf498df125c78faa7a5155572f3c0bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c1e7dd06326c9aa6310e71a4ab13930);
#
#
#             map_2c1e7dd06326c9aa6310e71a4ab13930.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_44a1e422efe00fcb9e196d1c1a982160_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#fdd6a3&quot;, &quot;fillColor&quot;: &quot;#fdd6a3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fee8c8&quot;, &quot;fillColor&quot;: &quot;#fee8c8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#fdd8a6&quot;, &quot;fillColor&quot;: &quot;#fdd8a6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fddbac&quot;, &quot;fillColor&quot;: &quot;#fddbac&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#7f0000&quot;, &quot;fillColor&quot;: &quot;#7f0000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#feeace&quot;, &quot;fillColor&quot;: &quot;#feeace&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#f98254&quot;, &quot;fillColor&quot;: &quot;#f98254&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#fdc892&quot;, &quot;fillColor&quot;: &quot;#fdc892&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#f2704c&quot;, &quot;fillColor&quot;: &quot;#f2704c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#fdc791&quot;, &quot;fillColor&quot;: &quot;#fdc791&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#fff5e7&quot;, &quot;fillColor&quot;: &quot;#fff5e7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#fff7ec&quot;, &quot;fillColor&quot;: &quot;#fff7ec&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#fdd49f&quot;, &quot;fillColor&quot;: &quot;#fdd49f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;#fdd6a2&quot;, &quot;fillColor&quot;: &quot;#fdd6a2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;27&quot;:
#                     return {&quot;color&quot;: &quot;

# %%
for year in years[1:]:
    print(f"{year}...")
    prev_year = year - 1
    nuts_dens[f"density_trend_{year}"] = nuts_dens[f"density_{year}"] - nuts_dens[f"density_{prev_year}"]
    
nuts_dens.head()
# Out:
# 2015...
# 2016...
# 2017...
# 2018...
# 2019...
# 2020...
# 2021...
# 2022...
#   NUTS_ID  LEVL_CODE CNTR_CODE     NAME_LATN     NUTS_NAME  MOUNT_TYPE  \
# 0      FR          0        FR        France        France         0.0
# 1      HR          0        HR      Hrvatska      Hrvatska         0.0
# 2      HU          0        HU  Magyarország  Magyarország         0.0
# 3      AL          0        AL     Shqipëria     Shqipëria         0.0
# 4      AT          0        AT    Österreich    Österreich         0.0
#
#    URBN_TYPE  COAST_TYPE FID  \
# 0          0           0  FR
# 1          0           0  HR
# 2          0           0  HU
# 3          0           0  AL
# 4          0           0  AT
#
#                                             geometry  ...  density_2021  \
# 0  MULTIPOLYGON (((9954236.116 -3059379.316, 9961...  ...    105.922303
# 1  MULTIPOLYGON (((4827385.889 2618351.326, 48483...  ...     71.330521
# 2  POLYGON ((5214660.069 2880853.832, 5216710.220...  ...    104.668134
# 3  POLYGON ((5129579.170 2204098.752, 5148385.473...  ...     98.725738
# 4  POLYGON ((4742889.368 2876362.725, 4783217.798...  ...    106.530037
#
#    density_2022  density_trend_2015  density_trend_2016  density_trend_2017  \
# 0    106.259284            0.457422            0.282178            0.268380
# 1     68.254707           -0.379825           -0.612282           -0.644251
# 2    104.218925           -0.234425           -0.269835           -0.354144
# 3     97.464550           -0.230195           -0.356003            0.034854
# 4    107.081788            0.919964            1.377978            0.863363
#
#    density_trend_2018  density_trend_2019  density_trend_2020  \
# 0            0.338805            0.237048            0.223221
# 1           -0.860981           -0.516853           -0.319528
# 2           -0.206415           -0.060397           -0.034743
# 3           -0.218647           -0.275515           -0.574685
# 4            0.589163            0.435391            0.504334
#
#    density_trend_2021  density_trend_2022
# 0            0.526766            0.336981
# 1           -0.385427           -3.075814
# 2           -0.416854           -0.449209
# 3           -0.565684           -1.261188
# 4            0.376858            0.551752
#
# [5 rows x 27 columns]

# %%
show_density(nuts_dens, 2022, "density_trend")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fb069a2246bb62826b53d70dc7c94f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fb069a2246bb62826b53d70dc7c94f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fb069a2246bb62826b53d70dc7c94f0 = L.map(
#                 &quot;map_5fb069a2246bb62826b53d70dc7c94f0&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5fb069a2246bb62826b53d70dc7c94f0);
#
#
#
#
#
#             var tile_layer_767cd7455f03ff3a2899512850b7d47e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fb069a2246bb62826b53d70dc7c94f0);
#
#
#             map_5fb069a2246bb62826b53d70dc7c94f0.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_40251605185a2d90c1d4183f50585300_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#dd3e2a&quot;, &quot;fillColor&quot;: &quot;#dd3e2a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fc9c67&quot;, &quot;fillColor&quot;: &quot;#fc9c67&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#e9573d&quot;, &quot;fillColor&quot;: &quot;#e9573d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#f26e4c&quot;, &quot;fillColor&quot;: &quot;#f26e4c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#da3724&quot;, &quot;fillColor&quot;: &quot;#da3724&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#bb0b07&quot;, &quot;fillColor&quot;: &quot;#bb0b07&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;27&quot;:
#                     return {&quot;color&quot;: &quot;#ec5f43&quot;, &quot;fillColor&quot;: &quot;#ec5f43&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#c3150e&quot;, &quot;fillColor&quot;: &quot;#c3150e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#d32a1b&quot;, &quot;fillColor&quot;: &quot;#d32a1b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#de3f2b&quot;, &quot;fillColor&quot;: &quot;#de3f2b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#df412c&quot;, &quot;fillColor&quot;: &quot;#df412c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#d62f1e&quot;, &quot;fillColor&quot;: &quot;#d62f1e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#e24831&quot;, &quot;fillColor&quot;: &quot;#e24831&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#df432d&quot;, &quot;fillColor&quot;: &quot;#df432d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#e34b34&quot;, &quot;fillColor&quot;: &quo

# %%
def show_density_diff(df, start, end):
    column = f"density_trend_{end}_{start}"
    df[column] = df[f"density_{end}"] - df[f"density_{start}"]
    return df.explore(column, legend=True, cmap='OrRd')

show_density_diff(nuts_dens, 2014, 2022)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6733849ba647c1309c51030c36d283 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6733849ba647c1309c51030c36d283&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6733849ba647c1309c51030c36d283 = L.map(
#                 &quot;map_cb6733849ba647c1309c51030c36d283&quot;,
#                 {
#                     center: [29.691996401945982, -3.6250856653385846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cb6733849ba647c1309c51030c36d283);
#
#
#
#
#
#             var tile_layer_63159681bef460e38cc09b6290846850 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb6733849ba647c1309c51030c36d283);
#
#
#             map_cb6733849ba647c1309c51030c36d283.fitBounds(
#                 [[-21.390765204928847, -63.08825311685313], [80.77475800882081, 55.83808178617596]],
#                 {}
#             );
#
#
#         function geo_json_fe99dedd220a84e84a7f5e28bb3ce18d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fdd39d&quot;, &quot;fillColor&quot;: &quot;#fdd39d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fff1de&quot;, &quot;fillColor&quot;: &quot;#fff1de&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#fee4bf&quot;, &quot;fillColor&quot;: &quot;#fee4bf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#fee8c9&quot;, &quot;fillColor&quot;: &quot;#fee8c9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#fdc68f&quot;, &quot;fillColor&quot;: &quot;#fdc68f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#fb8a58&quot;, &quot;fillColor&quot;: &quot;#fb8a58&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#fee9ca&quot;, &quot;fillColor&quot;: &quot;#fee9ca&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#fa8757&quot;, &quot;fillColor&quot;: &quot;#fa8757&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fdc892&quot;, &quot;fillColor&quot;: &quot;#fdc892&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#fddcaf&quot;, &quot;fillColor&quot;: &quot;#fddcaf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#fdc089&quot;, &quot;fillColor&quot;: &quot;#fdc089&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#fddbad&quot;, &quot;fillColor&quot;: &quot;#fddbad&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#fdd6a3&quot;, &quot;fillColor&quot;: &quot;#fdd6a3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#fdd49f&quot;, &quot;fillColor&quot;: &quot;#fdd49f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;#fda973&quot;, &quot;
